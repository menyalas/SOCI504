# %% [markdown]
# df = pd.read_fwf('sd17-al.txt', sep=" ", header=None)
# df.columns = ["FIPS", "DisID", "DisName", "PopTot", "PopAge", "PopAgePov", "File", "Date"]

# %%
import pandas as pd
ColName = ["FIPS", "DisID", "DisName", "PopTot", "PopAge", "PopAgePov", "File", "Date"]
df = pd.read_fwf('sd17-al.txt', sep="\s+", names=ColName, dtype={'FIPS':str, 'DisID':str})
print(df)
# Out:
#     FIPS  DisID                              DisName  PopTot  PopAge  \
# 0     01  00190       Alabaster City School District   34015    6703
# 1     01  00005     Albertville City School District   21786    4115
# 2     01  00030  Alexander City City School District   17073    2659
# 3     01  00060       Andalusia City School District    8854    1444
# 4     01  00090        Anniston City School District   22350    3184
# 5     01  00100            Arab City School District    8305    1520
# 6     01  00120          Athens City School District   24963    3948
# 7     01  00180         Attalla City School District    5952     927
# 8     01  00210          Auburn City School District   61570    7322
# 9     01  00240       Autauga County School District   55504    9990
# 10    01  00270       Baldwin County School District  212628   34538
# 11    01  00300       Barbour County School District   13182    1686
# 12    01  00330        Bessemer City School District   27717    4783
# ...

# %%
df.to_csv('sd17-al.csv')
dfNew = pd.read_fwf('sd17-al.csv')
print(dfNew)
# Out:
#     ,FIPS,DisID,DisName,PopTot,PopAge,PopAgePov,File,Date
# 0    0,01,00190,Alabaster City School District,3401...
# 1    1,01,00005,Albertville City School District,21...
# 2    2,01,00030,Alexander City City School District...
# 3    3,01,00060,Andalusia City School District,8854...
# 4    4,01,00090,Anniston City School District,22350...
# 5    5,01,00100,Arab City School District,8305,1520...
# 6    6,01,00120,Athens City School District,24963,3...
# 7    7,01,00180,Attalla City School District,5952,9...
# 8    8,01,00210,Auburn City School District,61570,7...
# 9    9,01,00240,Autauga County School District,5550...
# 10   10,01,00270,Baldwin County School District,212...
# 11   11,01,00300,Barbour County School District,131...
# 12   12,01,00330,Bessemer City School District,2771...
# 13   13,01,00360,Bibb County School District,22668,...
# 14   14,01,00390,Birmingham City School District,21...
# 15   15,01,00420,Blount County School District,5135...
# ...

# %%
import pandas as pd
df = pd.read_fwf('sd17-al.txt')
print(df)
# Out:
#      01  00190       Alabaster City School District   34015   6703    860  \
# 0     1      5     Albertville City School District   21786   4115   1546
# 1     1     30  Alexander City City School District   17073   2659    832
# 2     1     60       Andalusia City School District    8854   1444    386
# 3     1     90        Anniston City School District   22350   3184   1106
# 4     1    100            Arab City School District    8305   1520    329
# 5     1    120          Athens City School District   24963   3948    685
# 6     1    180         Attalla City School District    5952    927    280
# 7     1    210          Auburn City School District   61570   7322    888
# 8     1    240       Autauga County School District   55504   9990   1842
# 9     1    270       Baldwin County School District  212628  34538   4871
# 10    1    300       Barbour County School District   13182   1686    726
# 11    1    330        Bessemer City School District   27717   4783   1510
# ...

# %%
df.to_csv('sd17-al.csv')
dfNew = pd.read_fwf('sd17-al.csv')
print(dfNew)
# Out:
#     ,01,00190,Alabaster City School District,34015,6703,860,sd17-al.txt,06NOV2018
# 0    0,1,5,Albertville City School District,21786,4...
# 1    1,1,30,Alexander City City School District,170...
# 2    2,1,60,Andalusia City School District,8854,144...
# 3    3,1,90,Anniston City School District,22350,318...
# 4    4,1,100,Arab City School District,8305,1520,32...
# 5    5,1,120,Athens City School District,24963,3948...
# 6    6,1,180,Attalla City School District,5952,927,...
# 7    7,1,210,Auburn City School District,61570,7322...
# 8    8,1,240,Autauga County School District,55504,9...
# 9    9,1,270,Baldwin County School District,212628,...
# 10   10,1,300,Barbour County School District,13182,...
# 11   11,1,330,Bessemer City School District,27717,4...
# 12   12,1,360,Bibb County School District,22668,334...
# 13   13,1,390,Birmingham City School District,21236...
# 14   14,1,420,Blount County School District,51356,9...
# 15   15,1,12,Boaz City School District,9666,1761,49...
# ...
